# %%
import pandas as pd

# %%
majong_1=pd.read_excel('C:/Users/wjswp/Documents/GitHub/HorceRacingPrediction2023/Jaehoon/0~1000마종데이터.xls')
majong_2=pd.read_excel('C:/Users/wjswp/Documents/GitHub/HorceRacingPrediction2023/Jaehoon/1001~1500마종데이터.xls')
majong_3=pd.read_excel('C:/Users/wjswp/Documents/GitHub/HorceRacingPrediction2023/Jaehoon/1501~마종데이터.xls')

# %%
majong_1['ini_price','horse_item','dad_rate','mom_rate']
# Out:
#         ini_price                                              sicks  \
# 0             NaN  ['좌전지파행 2020/08/15', '좌전지파행 2020/08/14', '운동기질...
# 1             NaN  ['정치 2017/08/12', '낭치 2017/08/12', '일본뇌염예방접종 2...
# 2             NaN  ['정치 2019/04/03', '식이성 식욕부진 2016/09/04', '정치 2...
# 3             NaN  ['운동기인성 피로회복 2019/12/20', '좌각막염 2019/12/14', '...
# 4    10,000천원(개별)  ['운동기질환 기타 2019/05/26', '운동기질환 기타 2019/05/25',...
# ..            ...                                                ...
# 995  15,000천원(개별)  ['운동기질환 기타 2020/05/22', '운동기질환 기타 2020/05/21',...
# 996          자가생산  ['감기 2020/03/27', '감기 2020/03/26', '감기 2020/03...
# 997  21,000천원(개별)                 ['정치 2019/11/08', '낭치 2019/11/08']
# 998   7,000천원(개별)  ['우전지파행 2023/07/02', '우전지파행 2023/07/01', '우전지파...
# 999   1,640천원(개별)  ['우전지파행 2019/12/21', '정치 2019/09/26', '낭치 2019...
#
#                                                  ranks  \
# 0    ['제4 2020/01/01 ~ 2021/05/12', '제3 2019/08/04 ...
# ...
