# %%
import pandas as pd
import numpy as np

# %%
weather19 = pd.read_csv("../Data/weather2019.csv", encoding='cp949')
weather20 = pd.read_csv("../Data/weather2020.csv", encoding='cp949')
weather21 = pd.read_csv("../Data/weather2021.csv", encoding='cp949')
weather22 = pd.read_csv("../Data/weather2022.csv", encoding='cp949')
weather23 = pd.read_csv("../Data/weather2023.csv", encoding='cp949')

# %%
weather = pd.concat([weather19,weather20,weather21,weather22,weather23],axis=0)

# %%
weather = weather[weather["지점"]==184]

# %%
weather
# Out:
#        지점 지점명               일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  \
# 0     184  제주    2019.1.1 1:00     5.2       0.0      NaN        NaN      3.8
# 1     184  제주    2019.1.1 2:00     5.7       0.0      NaN        NaN      4.2
# 2     184  제주    2019.1.1 3:00     5.8       0.0      NaN        NaN      4.6
# 3     184  제주    2019.1.1 4:00     6.1       0.0      NaN        NaN      4.6
# 4     184  제주    2019.1.1 5:00     5.8       0.0      NaN        NaN      4.7
# ...   ...  ..              ...     ...       ...      ...        ...      ...
# 4315  184  제주  2023.6.29 20:00    28.9       NaN      NaN        NaN      5.5
# 4316  184  제주  2023.6.29 21:00    28.8       NaN      NaN        NaN      6.1
# 4317  184  제주  2023.6.29 22:00    28.5       NaN      NaN        NaN      5.8
# 4318  184  제주  2023.6.29 23:00    28.4       NaN      NaN        NaN      6.6
# 4319  184  제주   2023.6.30 0:00    25.2       NaN      0.9        NaN      3.9
#
# ...
